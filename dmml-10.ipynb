# %% [markdown]
# # DMML-10
#
# Recommendation Systems.
#
# David Apagyi
# 2025-11-27
#
# **Web page:** <a href="https://apagyidavid.web.elte.hu/2025-2026-1/dmml"
# target="_blank">apagyidavid.web.elte.hu/2025-2026-1/dmml</a>
#
# <a target="_blank" href="https://colab.research.google.com/github/dapagyi/dmml-web/blob/notebooks/dmml-10.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # Recommendation Systems
#
# Useful resources:
#
# -   <a href="http://www.mmds.org/" target="_blank">Ullman et al., Mining of
#     Massive Datasets</a>
#     (<a href="http://infolab.stanford.edu/~ullman/mmds/ch3n.pdf"
#     target="_blank">Chapter 3: Finding Similar Items,</a>
#     <a href="http://infolab.stanford.edu/~ullman/mmds/ch9.pdf"
#     target="_blank">Chapter 9: Recommendation Systems</a>)
# -   <a href="https://www.datacamp.com/tutorial/recommender-systems-python"
#     target="_blank">Beginner Tutorial: Recommender Systems in Python
#     (Datacamp)</a>
# -   <a href="https://www.datacamp.com/tutorial/streaming-platform-analysis"
#     target="_blank">Recommendation System for Streaming Platforms Tutorial
#     (Datacamp)</a>
# -   <a href="https://en.wikipedia.org/wiki/Recommender_system"
#     target="_blank">Wikipedia: Recommender System</a>
#
# ## Demo
#
# Clone
# <a href="https://github.com/dapagyi/dmml-recsys" target="_blank">this
# repository:</a>
#
# ``` bash
# git clone git@github.com:dapagyi/dmml-recsys.git
# ```
#
# Then, navigate to the folder and start the demo API (e.g. using `uv` as
# <a href="https://docs.astral.sh/uv/" target="_blank">package and
# dependency manager</a>):
#
# ``` bash
# cd dmml-recsys/dmml-recsys-api
# uv run litestar --app src.app:app run --host 0.0.0.0 --port 8000
# ```
#
# Set `http://localhost:8000` as your API URL
# <a href="https://apagyidavid.web.elte.hu/2025-2026-1/dmml/recsys"
# target="_blank">in the frontend application.</a>
#
# While developing, you can test your recommenders separately:
#
#     (dmml-recsys-api) david@david-thinkpad:~/code/dmml-packages/dmml-recsys/dmml-recsys-api$ python src/rec_test.py
#     Top 5 tag-based recommendations for item_id 1 (Toy Story):
#     Item ID: 2355 (A Bug's Life), Score: 0.9013892751944388
#     Item ID: 3114 (Toy Story 2), Score: 0.5772673193368394
#     Item ID: 122918 (Guardians of the Galaxy 2), Score: 0.4330096702897574
#     Item ID: 68954 (Up), Score: 0.2260398610190949
#     Item ID: 115617 (Big Hero 6), Score: 0.15214187468804743
#
# **Exercise:** Try to come up with your own recommendation algorithm and
# implement it in the demo API (in the `src/recommenders.py` file).
