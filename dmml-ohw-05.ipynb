# %% [markdown]
# # DMML-OHW-05
#
# **Honlap:** <a href="https://apagyidavid.web.elte.hu/2025-2026-1/dmml"
# target="_blank">apagyidavid.web.elte.hu/2025-2026-1/dmml</a>
#
# <a target="_blank" href="https://colab.research.google.com/github/dapagyi/dmml-web/blob/notebooks/dmml-ohw-05.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # Vizsgakérdések
#
# A megajánlott előadásjegyért menő írásbeli vizsgán olyan
# feleletválasztós kérdések szerepelnek majd (legalábbis tavaly így volt,
# az idei évet nem garantálom, és nincs is rá ráhatásom), amelyekben a
# négy lehetőség közül kell kiválasztani a pontosan egy helyes vagy
# pontosan egy hibás állítást. (Azt tehát nem tudjuk előre, hogy melyik
# eset áll fenn.)
#
# Ebben a szorgalmiban az a feladat, hogy az előadásanyagokat átpörgetve
# (ezáltal is már részben a vizsgára készülve) gyűjts össze fenti típusú
# kérdéseket. Ezekhez írd meg a helyes válaszokat, és nagyon röviden
# indokold is meg őket. (Azaz magyarázd meg, miért igazak vagy miért
# hamisak az egyes lehetőségek.)
#
# Kérdésenként (négy lehetőség, helyes válasz, indoklás) fél-fél pont jár,
# összesen legfeljebb három pont szerezhető.
#
# (Az a terv, hogy ezeket megnéznénk az utolsó órán gyakorlásként.)
#
# Ötletek feladattípusokra:
#
# -   fogalmak, definíciók;
# -   tételek feltételei;
# -   algoritmus vagy modell működése, jellemzői; stb.
#
# Néhány példa, de ezeknél jóval egyszerűbbeket is nyugodtan lehet írni:
#
# 1.  A VC-dimenzió…
#     1.  mindig pozitív egész szám.
#     2.  lehet negatív.
#     3.  alsó korlát abban az értelemben, hogy ha egy $\mathcal{F}$
#         klasszifikátorosztályra $\dim_\text{VC}(\mathcal{F})=d$, akkor
#         az alaphalmaz minden legalább $d$ méretű $A$ részhalmazának
#         minden címkézéséhez létezik egy $\mathcal{F}$-beli
#         klasszifikátor, amely helyesen osztályozza az $A$-beli pontokat.
#     4.  alsó korlát abban az értelemben, hogy ha egy $\mathcal{F}$
#         klasszifikátorosztályra $\dim_\text{VC}(\mathcal{F})=d$, akkor
#         létezik az alaphalmaznak olyan $d$ méretű $A$ részhalmaza,
#         amelynek minden címkézéséhez létezik olyan $\mathcal{F}$-beli
#         klasszifikátor, amely helyesen osztályozza az $A$-beli pontokat.
# 2.  A VC-dimenzió…
#     1.  (azonos alaphalmaz felett) kevesebb paraméterrel rendelkező
#         klasszifikátorosztályok esetén mindig szigorúan kisebb.
#         (*Paraméterként – praktikus korlátokat nem figyelembe véve –
#         tetszőleges valós számra gondolhatunk.*)
#     2.  monoton halmazfüggvény, azaz
#         $\mathcal{H}_1 \subseteq \mathcal{H}_2$ halmazrendszerek esetén
#         teljesül, hogy
#         $\dim_\text{VC}(\mathcal{H}_1) \leq \dim_\text{VC}(\mathcal{H}_2)$.
#     3.  az $\mathcal{X}=\mathbb{R}^d$ alaphalmaz felett lineáris
#         klasszifikátorokra éppen $d+1$.
#     4.  véges halmazrendszerre mindig véges.
# 3.  Bináris klasszifikáció esetén…
#     1.  az $F_1$-score mindig legalább annyi, mint a precision és a
#         recall számtani közepe.
#     2.  az $F_1$-score mindig legfeljebb annyi, mint a precision és a
#         recall számtani közepe.
#     3.  az accuracy mindig egyenlő a precision és a recall mértani
#         közepével.
#     4.  az accuracy mindig egyenlő a precision és a recall négyzetes
#         közepével.
